# %%
from __future__ import print_function
import os
data_path = [ './']

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
import pandas as pd
import numpy as np

filepath = os.sep.join(data_path + ['pd_speech_features.csv'])
data = pd.read_csv(filepath, sep=',')

# %%
data
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0      0       1  0.85247  0.71826  0.57227        240               239
# 1      0       1  0.76686  0.69481  0.53966        234               233
# 2      0       1  0.85083  0.67604  0.58982        232               231
# 3      1       0  0.41121  0.79672  0.59257        178               177
# 4      1       0  0.32790  0.79782  0.53028        236               235
# ..   ...     ...      ...      ...      ...        ...               ...
# 751  250       0  0.80903  0.56355  0.28385        417               416
# 752  250       0  0.16084  0.56499  0.59194        415               413
# 753  251       0  0.88389  0.72335  0.46815        381               380
# 754  251       0  0.83782  0.74890  0.49823        340               339
# 755  251       0  0.81304  0.76471  0.46374        340               339
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0            0.008064            0.000087       0.00218  ...
# 1            0.008258            0.000073       0.00195  ...
# 2            0.008340            0.000060       0.00176  ...
# 3            0.010858            0.000183       0.00419  ...
# 4            0.008162            0.002669       0.00535  ...
# ..                ...                 ...           ...  ...
# 751          0.004627            0.000052       0.00064  ...
# 752          0.004550            0.000220       0.00143  ...
# 753          0.005069            0.000103       0.00076  ...
# 754          0.005679            0.000055       0.00092  ...
# 755          0.005676            0.000037       0.00078  ...
#
#      tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                       1.5620                     2.6445
# 1                       1.5589                     3.6107
# 2                       1.5643                     2.3308
# 3                       3.7805                     3.5664
# 4                       6.1727                     5.8416
# ..                         ...                        ...
# 751                     3.0706                     3.0190
# 752                     1.9704                     1.7451
# 753                    51.5607                    44.4641
# 754                    19.1607                    12.8312
# 755                    62.9927                    21.8152
#
#      tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 0                       3.8686                     4.2105
# 1                      23.5155                    14.1962
# 2                       9.4959                    10.7458
# 3                       5.2558                    14.0403
# 4                       6.0805                     5.7621
# ..                         ...                        ...
# 751                     3.1212                     2.4921
# 752                     1.8277                     2.4976
# 753                    26.1586                     6.3076
# 754                     8.9434                     2.2044
# 755                     9.2457                     4.8555
#
#      tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 0                       5.1221                     4.4625
# 1                      11.0261                     9.5082
# 2                      11.0177                     4.8066
# 3                       4.2235                     4.6857
# 4                       7.7817                    11.6891
# ..                         ...                        ...
# 751                     3.5844                     3.5400
# 752                     5.2981                     4.2616
# 753                     2.8601                     2.5361
# 754                     1.9496                     1.9664
# 755                     3.0551                     3.0415
#
#      tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 0                       2.6202                     3.0004
# 1                       6.5245                     6.3431
# 2                       2.9199                     3.1495
# 3                       4.8460                     6.2650
# 4                       8.2103                     5.0559
# ..                         ...                        ...
# 751                     3.3805                     3.2003
# 752                     6.3042                    10.9058
# 753                     3.5377                     3.3545
# 754                     2.6801                     2.8332
# 755                     4.0116                     2.6217
#
#      tqwt_kurtosisValue_dec_36  class
# 0                      18.9405      1
# 1                      45.1780      1
# 2                       4.7666      1
# 3                       4.0603      1
# 4                       6.1164      1
# ..                         ...    ...
# 751                     6.8671      0
# 752                    28.4170      0
# 753                     5.0424      0
# 754                     3.7131      0
# 755                     3.1527      0
#
# [756 rows x 755 columns]

# %%
# drop 'id' column
data = data.drop('id', axis=1)
data
# Out:
#      gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0         1  0.85247  0.71826  0.57227        240               239
# 1         1  0.76686  0.69481  0.53966        234               233
# 2         1  0.85083  0.67604  0.58982        232               231
# 3         0  0.41121  0.79672  0.59257        178               177
# 4         0  0.32790  0.79782  0.53028        236               235
# ..      ...      ...      ...      ...        ...               ...
# 751       0  0.80903  0.56355  0.28385        417               416
# 752       0  0.16084  0.56499  0.59194        415               413
# 753       0  0.88389  0.72335  0.46815        381               380
# 754       0  0.83782  0.74890  0.49823        340               339
# 755       0  0.81304  0.76471  0.46374        340               339
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0            0.008064            0.000087       0.00218      0.000018  ...
# 1            0.008258            0.000073       0.00195      0.000016  ...
# 2            0.008340            0.000060       0.00176      0.000015  ...
# 3            0.010858            0.000183       0.00419      0.000046  ...
# 4            0.008162            0.002669       0.00535      0.000044  ...
# ..                ...                 ...           ...           ...  ...
# 751          0.004627            0.000052       0.00064      0.000003  ...
# 752          0.004550            0.000220       0.00143      0.000006  ...
# 753          0.005069            0.000103       0.00076      0.000004  ...
# 754          0.005679            0.000055       0.00092      0.000005  ...
# 755          0.005676            0.000037       0.00078      0.000004  ...
#
#      tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                       1.5620                     2.6445
# 1                       1.5589                     3.6107
# 2                       1.5643                     2.3308
# 3                       3.7805                     3.5664
# 4                       6.1727                     5.8416
# ..                         ...                        ...
# 751                     3.0706                     3.0190
# 752                     1.9704                     1.7451
# 753                    51.5607                    44.4641
# 754                    19.1607                    12.8312
# 755                    62.9927                    21.8152
#
#      tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 0                       3.8686                     4.2105
# 1                      23.5155                    14.1962
# 2                       9.4959                    10.7458
# 3                       5.2558                    14.0403
# 4                       6.0805                     5.7621
# ..                         ...                        ...
# 751                     3.1212                     2.4921
# 752                     1.8277                     2.4976
# 753                    26.1586                     6.3076
# 754                     8.9434                     2.2044
# 755                     9.2457                     4.8555
#
#      tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 0                       5.1221                     4.4625
# 1                      11.0261                     9.5082
# 2                      11.0177                     4.8066
# 3                       4.2235                     4.6857
# 4                       7.7817                    11.6891
# ..                         ...                        ...
# 751                     3.5844                     3.5400
# 752                     5.2981                     4.2616
# 753                     2.8601                     2.5361
# 754                     1.9496                     1.9664
# 755                     3.0551                     3.0415
#
#      tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 0                       2.6202                     3.0004
# 1                       6.5245                     6.3431
# 2                       2.9199                     3.1495
# 3                       4.8460                     6.2650
# 4                       8.2103                     5.0559
# ..                         ...                        ...
# 751                     3.3805                     3.2003
# 752                     6.3042                    10.9058
# 753                     3.5377                     3.3545
# 754                     2.6801                     2.8332
# 755                     4.0116                     2.6217
#
#      tqwt_kurtosisValue_dec_36  class
# 0                      18.9405      1
# 1                      45.1780      1
# 2                       4.7666      1
# 3                       4.0603      1
# 4                       6.1164      1
# ..                         ...    ...
# 751                     6.8671      0
# 752                    28.4170      0
# 753                     5.0424      0
# 754                     3.7131      0
# 755                     3.1527      0
#
# [756 rows x 754 columns]

# %%
# y = (data['color'] == 'red').astype(int)
y = data['class']
fields = list(data.columns[:-1])  # everything except "color"
correlations = data[fields].corrwith(y)
correlations.sort_values(inplace=True)
correlations
# Out:
# tqwt_stdValue_dec_12      -0.393029
# tqwt_maxValue_dec_12      -0.391288
# tqwt_stdValue_dec_11      -0.391081
# tqwt_entropy_log_dec_12   -0.381003
# tqwt_maxValue_dec_11      -0.378485
#                              ...
# std_9th_delta_delta        0.364333
# tqwt_minValue_dec_13       0.365264
# tqwt_minValue_dec_11       0.366552
# tqwt_minValue_dec_12       0.395740
# mean_MFCC_2nd_coef         0.398695
# Length: 753, dtype: float64

# %%
ax = correlations.plot(kind='bar')
ax.set(ylim=[-1, 1], ylabel='pearson correlation');

# %%
feature_cols = [x for x in data.columns if x not in 'class']

# %%
strat_shuff_split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

# Get the index values from the generator
train_idx, test_idx = next(strat_shuff_split.split(data[feature_cols], data['class']))

# Create the data sets
X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'class']

X_test = data.loc[test_idx, feature_cols]
y_test = data.loc[test_idx, 'class']

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((529, 753), (227, 753), (529,), (227,))

# %%
print(y_train.value_counts(normalize=True).sort_index())
print(y_test.value_counts(normalize=True).sort_index())
# Out:
# 0    0.253308
# 1    0.746692
# Name: class, dtype: float64
# 0    0.255507
# 1    0.744493
# Name: class, dtype: float64

# %%
mmsc = MinMaxScaler()

X_minmax_train = pd.DataFrame(mmsc.fit_transform(X_train), columns=feature_cols)
X_minmax_test = pd.DataFrame(mmsc.transform(X_test), columns=feature_cols)
X_minmax_train
# Out:
#      gender       PPE       DFA      RPDE  numPulses  numPeriodsPulses  \
# 0       1.0  0.717368  0.928834  0.685291   0.227778          0.234160
# 1       1.0  0.900625  0.394121  0.649490   0.268056          0.274105
# 2       0.0  0.900197  0.379072  0.153789   0.436111          0.440771
# 3       1.0  0.905174  0.301318  0.560331   0.243056          0.249311
# 4       0.0  0.913937  0.318373  0.280273   0.347222          0.352617
# ..      ...       ...       ...       ...        ...               ...
# 524     1.0  0.359192  0.900676  0.683034   0.208333          0.214876
# 525     0.0  0.928762  0.006923  0.440805   0.565278          0.568871
# 526     1.0  0.903292  0.524982  0.622070   0.237500          0.243802
# 527     0.0  0.912990  0.645910  0.461898   0.438889          0.443526
# 528     0.0  0.917701  0.095813  0.230137   0.495833          0.500000
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0            0.569466            0.035103      0.196078      0.171286  ...
# 1            0.481645            0.030425      0.092593      0.073551  ...
# 2            0.256773            0.003687      0.014524      0.009007  ...
# 3            0.532487            0.015697      0.032680      0.030079  ...
# 4            0.355249            0.011089      0.026870      0.019054  ...
# ..                ...                 ...           ...           ...  ...
# 524          0.615728            0.066226      0.281046      0.257684  ...
# 525          0.160398            0.012961      0.013072      0.006153  ...
# 526          0.541684            0.028198      0.064633      0.056741  ...
# 527          0.254432            0.018203      0.038126      0.021400  ...
# 528          0.207095            0.005069      0.011256      0.006310  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 0                     0.001253                   0.001096
# 1                     0.000851                   0.004109
# 2                     0.381417                   0.275101
# 3                     0.001038                   0.001421
# 4                     0.024832                   0.584298
# ..                         ...                        ...
# 524                   0.001116                   0.000312
# 525                   0.739682                   0.721640
# 526                   0.001386                   0.000945
# 527                   0.278231                   0.239727
# 528                   0.645552                   0.514891
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 0                     0.017467                   0.017630
# 1                     0.334035                   0.545107
# 2                     0.324983                   0.261984
# 3                     0.005503                   0.010652
# 4                     0.584802                   0.616315
# ..                         ...                        ...
# 524                   0.013187                   0.183655
# 525                   0.771483                   0.858765
# 526                   0.044032                   0.017818
# 527                   0.317335                   0.314255
# 528                   0.506188                   0.531850
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 0                     0.016304                   0.024077
# 1                     0.635907                   0.771423
# 2                     0.087155                   0.047391
# 3                     0.013160                   0.020005
# 4                     0.723429                   0.934462
# ..                         ...                        ...
# 524                   0.173538                   0.153170
# 525                   0.857194                   0.806341
# 526                   0.013503                   0.016896
# 527                   0.095970                   0.075010
# 528                   0.552174                   0.743861
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 0                     0.040765                   0.040284
# 1                     0.806359                   0.696448
# 2                     0.043529                   0.028637
# 3                     0.039187                   0.026685
# 4                     0.901537                   0.824702
# ..                         ...                        ...
# 524                   0.214697                   0.691071
# 525                   0.765640                   0.653818
# 526                   0.019738                   0.076578
# 527                   0.084877                   0.502512
# 528                   0.896650                   0.936697
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 0                     0.058379                   0.021953
# 1                     0.725671                   0.762038
# 2                     0.032050                   0.003375
# 3                     0.017500                   0.008683
# 4                     0.885593                   0.769444
# ..                         ...                        ...
# 524                   0.759223                   0.417778
# 525                   0.388005                   0.006631
# 526                   0.082092                   0.031648
# 527                   0.807987                   0.764781
# 528                   0.938661                   0.787982
#
# [529 rows x 753 columns]

# %%
stdsc = StandardScaler()

X_standard_train = pd.DataFrame(stdsc.fit_transform(X_train), columns=feature_cols)
X_standard_test = pd.DataFrame(stdsc.transform(X_test), columns=feature_cols)
X_standard_train
# Out:
#        gender       PPE       DFA      RPDE  numPulses  numPeriodsPulses  \
# 0    0.961060 -0.523756  1.851295  1.005378  -0.829721         -0.824966
# 1    0.961060  0.447063 -0.424657  0.828423  -0.532341         -0.528118
# 2   -1.040518  0.444800 -0.488712 -1.621665   0.708451          0.710453
# 3    0.961060  0.471162 -0.819664  0.387739  -0.716922         -0.712368
# 4   -1.040518  0.517587 -0.747068 -0.996493   0.052164          0.055341
# ..        ...       ...       ...       ...        ...               ...
# 524  0.961060 -2.421234  1.731441  0.994221  -0.973283         -0.968271
# 525 -1.040518  0.596124 -2.072725 -0.203036   1.662117          1.662412
# 526  0.961060  0.461192  0.132339  0.692899  -0.757939         -0.753313
# 527 -1.040518  0.512571  0.647058 -0.098782   0.728959          0.730925
# 528 -1.040518  0.537527 -1.694373 -1.244302   1.149393          1.150606
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0            0.846335           -0.343173      1.094912      1.055203  ...
# 1            0.385059           -0.365631      0.111419      0.069853  ...
# 2           -0.796066           -0.493999     -0.630515     -0.580872  ...
# 3            0.652104           -0.436337     -0.457972     -0.368431  ...
# 4           -0.278828           -0.458462     -0.513186     -0.479578  ...
# ..                ...                 ...           ...           ...  ...
# 524          1.089320           -0.193756      1.902412      1.926252  ...
# 525         -1.302270           -0.449474     -0.644318     -0.609644  ...
# 526          0.700409           -0.376321     -0.154297     -0.099627  ...
# 527         -0.808360           -0.424307     -0.406209     -0.455930  ...
# 528         -1.056998           -0.487362     -0.661572     -0.608068  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 0                    -0.468858                  -0.604355
# 1                    -0.471066                  -0.590013
# 2                     1.619098                   0.699845
# 3                    -0.470042                  -0.602806
# 4                    -0.339358                   2.171545
# ..                         ...                        ...
# 524                  -0.469611                  -0.608085
# 525                   3.586780                   2.825257
# 526                  -0.468132                  -0.605070
# 527                   1.052373                   0.531472
# 528                   3.069790                   1.841186
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 0                    -0.582675                  -0.598357
# 1                     0.963551                   1.857822
# 2                     0.919336                   0.539470
# 3                    -0.641111                  -0.630850
# 4                     2.188379                   2.189402
# ..                         ...                        ...
# 524                  -0.603580                   0.174731
# 525                   3.100195                   3.318361
# 526                  -0.452922                  -0.597485
# 527                   0.881979                   0.782869
# 528                   1.804404                   1.796092
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 0                    -0.536424                  -0.490521
# 1                     2.491616                   2.891754
# 2                    -0.190170                  -0.385008
# 3                    -0.551787                  -0.508946
# 4                     2.919339                   3.629624
# ..                         ...                        ...
# 524                   0.231989                   0.093718
# 525                   3.573057                   3.049783
# 526                  -0.550113                  -0.523018
# 527                  -0.147093                  -0.260011
# 528                   2.082407                   2.767017
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 0                    -0.499304                  -0.689215
# 1                     2.724397                   1.761654
# 2                    -0.487669                  -0.732718
# 3                    -0.505949                  -0.740008
# 4                     3.125163                   2.240701
# ..                         ...                        ...
# 524                   0.233072                   1.741571
# 525                   2.552939                   1.602425
# 526                  -0.587846                  -0.553654
# 527                  -0.313563                   1.037275
# 528                   3.104588                   2.659018
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 0                    -0.702862                  -0.790164
# 1                     1.576951                   1.749492
# 2                    -0.792816                  -0.853915
# 3                    -0.842526                  -0.835700
# 4                     2.123328                   1.774908
# ..                         ...                        ...
# 524                   1.691581                   0.568141
# 525                   0.423310                  -0.842740
# 526                  -0.621847                  -0.756894
# 527                   1.858186                   1.758907
# 528                   2.304635                   1.838522
#
# [529 rows x 753 columns]

# %%
def specificity_score(y_true, y_pred):
    cf = confusion_matrix(y_true, y_pred)
    return cf[0,0]/(cf[0,0]+cf[0,1])

def measure_error(y_true, y_pred, label):
    return pd.Series({'accuracy':accuracy_score(y_true, y_pred),
                      'precision': precision_score(y_true, y_pred),
                      'recall': recall_score(y_true, y_pred),
                      'specificity': specificity_score(y_true, y_pred),
                      'balanced accuracy': balanced_accuracy_score(y_true, y_pred),
                      'f1': f1_score(y_true, y_pred)},
                      name=label)

# %%
LSVC = LinearSVC()
LSVC.fit(X_train, y_train)

y_train_pred = LSVC.predict(X_train)
y_test_pred = LSVC.predict(X_test)

print(confusion_matrix(y_true=y_test, y_pred=y_test_pred))

train_test_error = pd.concat([measure_error(y_train, y_train_pred, 'train'), 
                              measure_error(y_test, y_test_pred, 'test')], axis=1)
train_test_error
# Out:
# [[  0  58]
#  [  1 168]]
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#                       train      test
# accuracy           0.746692  0.740088
# precision          0.746692  0.743363
# recall             1.000000  0.994083
# specificity        0.000000  0.000000
# balanced accuracy  0.500000  0.497041
# f1                 0.854978  0.850633

# %%
LSVC = LinearSVC(max_iter=10000)
LSVC.fit(X_minmax_train, y_train)

y_minmax_train_pred = LSVC.predict(X_minmax_train)
y_minmax_test_pred = LSVC.predict(X_minmax_test)

print(confusion_matrix(y_true=y_test, y_pred=y_minmax_test_pred))

minmax_train_test_error = pd.concat([measure_error(y_train, y_minmax_train_pred, 'minmax_train'), 
                                     measure_error(y_test, y_minmax_test_pred, 'minmax_test')], axis=1)
minmax_train_test_error
# Out:
# [[ 38  20]
#  [  8 161]]
#                    minmax_train  minmax_test
# accuracy                    1.0     0.876652
# precision                   1.0     0.889503
# recall                      1.0     0.952663
# specificity                 1.0     0.655172
# balanced accuracy           1.0     0.803918
# f1                          1.0     0.920000

# %%
LSVC = LinearSVC(max_iter=10000)
LSVC.fit(X_standard_train, y_train)

y_standard_train_pred = LSVC.predict(X_standard_train)
y_standard_test_pred = LSVC.predict(X_standard_test)

print(confusion_matrix(y_true=y_test, y_pred=y_standard_test_pred))

standard_train_test_error = pd.concat([measure_error(y_train, y_standard_train_pred, 'standard_train'), 
                                       measure_error(y_test, y_standard_test_pred, 'standard_test')], axis=1)
standard_train_test_error
# Out:
# [[ 38  20]
#  [ 19 150]]
#                    standard_train  standard_test
# accuracy                      1.0       0.828194
# precision                     1.0       0.882353
# recall                        1.0       0.887574
# specificity                   1.0       0.655172
# balanced accuracy             1.0       0.771373
# f1                            1.0       0.884956

# %%
gammas = [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.5, 1, 2, 10]
for gamma in gammas:
    # no-scaling
    print(f'<no-scaling, gamma={gamma}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=gamma)
    
    SVC_Gaussian.fit(X_train, y_train)
    
    y_train_pred = SVC_Gaussian.predict(X_train)
    y_test_pred = SVC_Gaussian.predict(X_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_test_pred))
    
    train_test_error = pd.concat([measure_error(y_train, y_train_pred, 'train'), 
                                  measure_error(y_test, y_test_pred, 'test')], axis=1)
    print(train_test_error, end='\n\n\n')
    
    # MinmaxScaler
    print(f'<MinMaxScaler, gamma={gamma}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=gamma)
    
    SVC_Gaussian.fit(X_minmax_train, y_train)
    
    y_minmax_train_pred = SVC_Gaussian.predict(X_minmax_train)
    y_minmax_test_pred = SVC_Gaussian.predict(X_minmax_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_minmax_test_pred))
    
    minmax_train_test_error = pd.concat([measure_error(y_train, y_minmax_train_pred, 'minmax_train'), 
                                         measure_error(y_test, y_minmax_test_pred, 'minmax_test')], axis=1)
    print(minmax_train_test_error, end='\n\n\n')
    
    
    # StandardScaler
    print(f'<Standard, gamma={gamma}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=gamma)
    
    SVC_Gaussian.fit(X_standard_train, y_train)
    
    y_standard_train_pred = SVC_Gaussian.predict(X_standard_train)
    y_standard_test_pred = SVC_Gaussian.predict(X_standard_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_standard_test_pred))
    
    standard_train_test_error = pd.concat([measure_error(y_train, y_standard_train_pred, 'standard_train'), 
                                           measure_error(y_test, y_standard_test_pred, 'standard_test')], axis=1)
    print(standard_train_test_error, end='\n\n\n')
# Out:
# <no-scaling, gamma=1e-05>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=1e-05>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, gamma=1e-05>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, gamma=0.0001>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=0.0001>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, gamma=0.0001>
# [[  9  49]
#  [  1 168]]
#              standard_train  standard_test
# accuracy           0.812854       0.779736
# precision          0.803279       0.774194
# recall             0.992405       0.994083
# specificity        0.283582       0.155172
# f1                 0.887882       0.870466
#
#
# <no-scaling, gamma=0.001>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=0.001>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, gamma=0.001>
# [[ 26  32]
#  [  3 166]]
#              standard_train  standard_test
# accuracy           0.914934       0.845815
# precision          0.901376       0.838384
# recall             0.994937       0.982249
# specificity        0.679104       0.448276
# f1                 0.945848       0.904632
#
#
# <no-scaling, gamma=0.01>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=0.01>
# [[ 28  30]
#  [  4 165]]
#              minmax_train  minmax_test
# accuracy         0.869565     0.850220
# precision        0.860619     0.846154
# recall           0.984810     0.976331
# specificity      0.529851     0.482759
# f1               0.918536     0.906593
#
#
# <Standard, gamma=0.01>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535
#
#
# <no-scaling, gamma=0.1>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=0.1>
# [[ 26  32]
#  [  4 165]]
#              minmax_train  minmax_test
# accuracy         0.931947     0.841410
# precision        0.922353     0.837563
# recall           0.992405     0.976331
# specificity      0.753731     0.448276
# f1               0.956098     0.901639
#
#
# <Standard, gamma=0.1>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535
#
#
# <no-scaling, gamma=0.5>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=0.5>
# [[  0  58]
#  [  1 168]]
#              minmax_train  minmax_test
# accuracy              1.0     0.740088
# precision             1.0     0.743363
# recall                1.0     0.994083
# specificity           1.0     0.000000
# f1                    1.0     0.850633
#
#
# <Standard, gamma=0.5>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535
#
#
# <no-scaling, gamma=1>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=1>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy              1.0     0.744493
# precision             1.0     0.744493
# recall                1.0     1.000000
# specificity           1.0     0.000000
# f1                    1.0     0.853535
#
#
# <Standard, gamma=1>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535
#
#
# <no-scaling, gamma=2>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=2>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy              1.0     0.744493
# precision             1.0     0.744493
# recall                1.0     1.000000
# specificity           1.0     0.000000
# f1                    1.0     0.853535
#
#
# <Standard, gamma=2>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535
#
#
# <no-scaling, gamma=10>
# [[  0  58]
#  [  0 169]]
#              train      test
# accuracy       1.0  0.744493
# precision      1.0  0.744493
# recall         1.0  1.000000
# specificity    1.0  0.000000
# f1             1.0  0.853535
#
#
# <MinMaxScaler, gamma=10>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy              1.0     0.744493
# precision             1.0     0.744493
# recall                1.0     1.000000
# specificity           1.0     0.000000
# f1                    1.0     0.853535
#
#
# <Standard, gamma=10>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy                1.0       0.744493
# precision               1.0       0.744493
# recall                  1.0       1.000000
# specificity             1.0       0.000000
# f1                      1.0       0.853535

# %%
Cs = [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.5, 1, 10]
for c in Cs:
    # no-scaling
    print(f'<no-scaling, c={c}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=0.01, C=c)
    
    SVC_Gaussian.fit(X_train, y_train)
    
    y_train_pred = SVC_Gaussian.predict(X_train)
    y_test_pred = SVC_Gaussian.predict(X_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_test_pred))
    
    train_test_error = pd.concat([measure_error(y_train, y_train_pred, 'train'), 
                                  measure_error(y_test, y_test_pred, 'test')], axis=1)
    print(train_test_error, end='\n\n\n')
    
    # MinmaxScaler
    print(f'<MinMaxScaler, c={c}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=0.01, C=c)
    
    SVC_Gaussian.fit(X_minmax_train, y_train)
    
    y_minmax_train_pred = SVC_Gaussian.predict(X_minmax_train)
    y_minmax_test_pred = SVC_Gaussian.predict(X_minmax_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_minmax_test_pred))
    
    minmax_train_test_error = pd.concat([measure_error(y_train, y_minmax_train_pred, 'minmax_train'), 
                                         measure_error(y_test, y_minmax_test_pred, 'minmax_test')], axis=1)
    print(minmax_train_test_error, end='\n\n\n')
    
    
    # StandardScaler
    print(f'<Standard, c={c}>')
    
    SVC_Gaussian = SVC(kernel='rbf', gamma=0.01, C=c)
    
    SVC_Gaussian.fit(X_standard_train, y_train)
    
    y_standard_train_pred = SVC_Gaussian.predict(X_standard_train)
    y_standard_test_pred = SVC_Gaussian.predict(X_standard_test)

    print(confusion_matrix(y_true=y_test, y_pred=y_standard_test_pred))
    
    standard_train_test_error = pd.concat([measure_error(y_train, y_standard_train_pred, 'standard_train'), 
                                           measure_error(y_test, y_standard_test_pred, 'standard_test')], axis=1)
    print(standard_train_test_error, end='\n\n\n')
# Out:
# <no-scaling, c=1e-05>
# [[  0  58]
#  [  0 169]]
#                 train      test
# accuracy     0.746692  0.744493
# precision    0.746692  0.744493
# recall       1.000000  1.000000
# specificity  0.000000  0.000000
# f1           0.854978  0.853535
#
#
# <MinMaxScaler, c=1e-05>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, c=1e-05>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, c=0.0001>
# [[  0  58]
#  [  0 169]]
#                 train      test
# accuracy     0.746692  0.744493
# precision    0.746692  0.744493
# recall       1.000000  1.000000
# specificity  0.000000  0.000000
# f1           0.854978  0.853535
#
#
# <MinMaxScaler, c=0.0001>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, c=0.0001>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, c=0.001>
# [[  0  58]
#  [  0 169]]
#                 train      test
# accuracy     0.746692  0.744493
# precision    0.746692  0.744493
# recall       1.000000  1.000000
# specificity  0.000000  0.000000
# f1           0.854978  0.853535
#
#
# <MinMaxScaler, c=0.001>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, c=0.001>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, c=0.01>
# [[  0  58]
#  [  0 169]]
#                 train      test
# accuracy     0.746692  0.744493
# precision    0.746692  0.744493
# recall       1.000000  1.000000
# specificity  0.000000  0.000000
# f1           0.854978  0.853535
#
#
# <MinMaxScaler, c=0.01>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, c=0.01>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, c=0.1>
# [[  0  58]
#  [  0 169]]
#                 train      test
# accuracy     0.746692  0.744493
# precision    0.746692  0.744493
# recall       1.000000  1.000000
# specificity  0.000000  0.000000
# f1           0.854978  0.853535
#
#
# <MinMaxScaler, c=0.1>
# [[  0  58]
#  [  0 169]]
#              minmax_train  minmax_test
# accuracy         0.746692     0.744493
# precision        0.746692     0.744493
# recall           1.000000     1.000000
# specificity      0.000000     0.000000
# f1               0.854978     0.853535
#
#
# <Standard, c=0.1>
# [[  0  58]
#  [  0 169]]
#              standard_train  standard_test
# accuracy           0.746692       0.744493
# precision          0.746692       0.744493
# recall             1.000000       1.000000
# specificity        0.000000       0.000000
# f1                 0.854978       0.853535
#
#
# <no-scaling, c=0.5>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [18], line 8
#       4 print(f'<no-scaling, c={c}>')
#       6 SVC_Gaussian = SVC(kernel='rbf', gamma=0.01, C=c)
# ----> 8 SVC_Gaussian.fit(X_train, y_train)
#      10 y_train_pred = SVC_Gaussian.predict(X_train)
#      11 y_test_pred = SVC_Gaussian.predict(X_test)
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:251, in BaseLibSVM.fit(self, X, y, sample_weight)
#     248     print("[LibSVM]", end="")
#     250 seed = rnd.randint(np.iinfo("i").max)
# --> 251 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     252 # see comment on the other call to np.iinfo in this file
#     254 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:333, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     319 libsvm.set_verbosity_wrap(self.verbose)
#     321 # we don't pass **self.get_params() to allow subclasses to
#     322 # add other parameters to __init__
#     323 (
#     324     self.support_,
#     325     self.support_vectors_,
#     326     self._n_support,
#     327     self.dual_coef_,
#     328     self.intercept_,
#     329     self._probA,
#     330     self._probB,
#     331     self.fit_status_,
#     332     self._num_iter,
# --> 333 ) = libsvm.fit(
#     334     X,
#     335     y,
#     336     svm_type=solver_type,
#     337     sample_weight=sample_weight,
#     338     class_weight=self.class_weight_,
#     339     kernel=kernel,
#     340     C=self.C,
#     341     nu=self.nu,
#     342     probability=self.probability,
#     343     degree=self.degree,
#     344     shrinking=self.shrinking,
#     345     tol=self.tol,
#     346     cache_size=self.cache_size,
#     347     coef0=self.coef0,
#     348     gamma=self._gamma,
#     349     epsilon=self.epsilon,
#     350     max_iter=self.max_iter,
#     351     random_seed=random_seed,
#     352 )
#     354 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
SVC_Gaussian = SVC(kernel='rbf')
GS = GridSearchCV(SVC_Gaussian, 
                  param_grid={
                      'gamma':[0.0001, 0.001, 0.01, 0.1, 1, 10], 
                      'C':[0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}, 
                  scoring=['accuracy', 'recall', 'balanced_accuracy'],
                  refit='balanced_accuracy')

GS.fit(X_train, y_train)

GS.best_params_, GS.best_score_
# Out:
# ({'C': 0.0001, 'gamma': 0.0001}, 0.5)

# %%
SVC_Gaussian = SVC(kernel='rbf')
GS = GridSearchCV(SVC_Gaussian, 
                  param_grid={
                      'gamma':[0.0001, 0.001, 0.01, 0.1, 1, 10], 
                      'C':[0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}, 
                  scoring=['accuracy', 'recall', 'balanced_accuracy'],
                  refit='balanced_accuracy')

GS.fit(X_minmax_train, y_train)

GS.best_params_, GS.best_score_
# Out:
# ({'C': 10, 'gamma': 0.1}, 0.830267950521115)

# %%
SVC_Gaussian = SVC(kernel='rbf')
GS = GridSearchCV(SVC_Gaussian, 
                  param_grid={
                      'gamma':[0.0001, 0.001, 0.01, 0.1, 1, 10], 
                      'C':[0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}, 
                  scoring=['accuracy', 'recall', 'balanced_accuracy'],
                  refit='balanced_accuracy')

GS.fit(X_standard_train, y_train)

GS.best_params_, GS.best_score_
# Out:
# ({'C': 10, 'gamma': 0.001}, 0.7866168992751271)

# %%
SVC_Gaussian = SVC(kernel='rbf', gamma=0.1, C=10)
SVC_Gaussian.fit(X_minmax_train, y_train)

y_minmax_train_pred = SVC_Gaussian.predict(X_minmax_train)
y_minmax_test_pred = SVC_Gaussian.predict(X_minmax_test)

print(confusion_matrix(y_true=y_test, y_pred=y_minmax_test_pred))

minmax_train_test_error = pd.concat([measure_error(y_train, y_minmax_train_pred, 'minmax_train'), 
                                     measure_error(y_test, y_minmax_test_pred, 'minmax_test')], axis=1)
minmax_train_test_error
# Out:
# [[ 44  14]
#  [  4 165]]
#                    minmax_train  minmax_test
# accuracy                    1.0     0.920705
# precision                   1.0     0.921788
# recall                      1.0     0.976331
# specificity                 1.0     0.758621
# balanced accuracy           1.0     0.867476
# f1                          1.0     0.948276
